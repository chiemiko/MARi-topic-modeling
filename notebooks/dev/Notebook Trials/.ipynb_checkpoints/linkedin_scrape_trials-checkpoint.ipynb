# %% [markdown]
# # Steps:
#
# - set up urls filters and tracking
# - run google chrome scrape
#
# - extraction of data and create data frame

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
from datetime import datetime
import urllib.request

import pandas as pd



class AppURLopener(urllib.request.FancyURLopener):
    version = "Mozilla/5.0"



def is_good_response(resp):
    """
    Returns 'True' if the response seems to be HTML, 'False' otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. This function just prints them, but you can make it do anything.
    """
    print(e)


def get_names(url):
    """
    Downloads the LinkedIn page to create a beautiful soup object with html information
    """
    
    try:
        with closing(get(url, stream=True)) as resp:
            #if is_good_response(resp):
            response = resp.content
                
                
            if response is not None:
                html = BeautifulSoup(response, 'lxml')
                    #print(html)
                return html
                # Raise an exception if we failed to get any data from the url
                #raise Exception('Error retrieving contents at {}'.format(url))

                
            #else:
             #   pass

    except RequestException as e:
        # MAIN ERROR? 
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# %%
def get_url(city, role):
    
    '''gets the url for the city (ie 'San Francisco, California') and job role (ie 'Data Scientist')'''
    search_city = ''
    search_state = ''
    location_string = ''
    search_role = ''
    
    '''Makes separate strings for city and state'''
    for i, word in enumerate(city.split()):
        if word[len(word)-1] == ',':
            
            for x in range(i+1):
                search_city = search_city + ' ' + city.split()[x]
                
            search_city = search_city[0:len(search_city)-1]
                        
            for x in range(i+1,len(city.split())):
                search_state = search_state+ ' ' + city.split()[x]
                # search_state = search_state + ' ' + city.split()[x]
                        
    for word in search_city.split():        
        location_string = location_string + '%20' + word

    location_string = location_string[3:len(location_string)] + '%2C'
        
    for word in search_state.split():
        location_string = location_string + '%20' + word
    
    '''Now for each city, search sites for each role in roles list'''
    
        
    for word in role.split():
        search_role = search_role + '%20' + word
    search_role = search_role[3:len(search_role)]
    url = f'https://www.linkedin.com/jobs/search?keywords={search_role}&location={location_string}%2C%20United%20States&trk=homepage-basic_jobs-search-bar_search-submit&redirect=false&position=1&pageNum=0'

    return url

# %%
get_url('New York, New York', 'Data Scientist')
# Out:
# 'https://www.linkedin.com/jobs/search?keywords=Data%20Scientist&location=New%20York%2C%20New%20York%2C%20United%20States&trk=homepage-basic_jobs-search-bar_search-submit&redirect=false&position=1&pageNum=0'

# %% [markdown]
# # For URL extraction

# %%
def get_divs(soup):
    urls = []
    soups = []
    companies = []
    titles = []
    descriptions = []
    locations = []
    post_dates = []
    
    '''Extract company names'''
    # for item in soup.find_all('a', attrs={'class': 'result-card__subtitle-link job-result-card__subtitle-link'}):        
        
    
    for i,item in enumerate(soup.find_all('h4', attrs={'class': 'result-card__subtitle job-result-card__subtitle'})):
        companies.append(item.text)
        
    #print()
    #<h4 class="result-card__subtitle job-result-card__subtitle">
    
    '''Extract location'''

    for item in soup.find_all('span', attrs={'class': 'job-result-card__location'}):
        locations.append(item.text)
    
    '''Extract title information'''
    for item in soup.find_all('span', attrs={'class': 'screen-reader-text'}):
        titles.append(item.text)

    '''Extract post date of position'''
    for item in soup.find_all('time'):
        post_dates.append(item.get('datetime'))
    
    #'''Extract descriptions'''
    #for item in soup.find_all('p', attrs={'class': 'job-result-card__snippet'}):
    #    descriptions.append(item.text)
    
    '''Extract urls'''
    for item in soup.find_all('a', href=True):

        if item.get('href')[29:34] == '/view':
            new_url = item.get('href')
            urls.append(new_url)
            
            print()

       
    '''
    print(len(companies))
    print(len(locations))
    
    print(len(titles))
    
    print(len(post_dates))
    #print(len(descriptions))
    print(len(urls))
    for item in urls:
        print(item)
    
    #print()
    #print('soup')
    #print(soup)
    
    '''
    # Make a dataframe object out of a dictionary of arrays
    df = pd.DataFrame({
        "company": companies,
        "location": locations,
        "title": titles,
        "post_date": post_dates,
        #"description": descriptions,
         "url": urls
    })
    
    return df

# %%
url = 'https://www.linkedin.com/jobs/search?keywords=Researcher&location=%2C%2C%20United%20States&trk=homepage-basic_jobs-search-bar_search-submit&redirect=false&position=1&pageNum=0'

soup = get_names(url)
df = get_divs(soup)
#info = get_linkedin_info(soup)
# df = get_divs(soup)
# Out:
# company  0 Commonwealth Sciences, Inc.
#
# company  1 IMS ExpertServices
#
# company  2 Fors Marsh Group
#
# company  3 Forrester
#
# company  4 LanceSoft, Inc.
#
# company  5 Rose International
#
# company  6 Nextdoor
#
# company  7 Intellipro Group Inc
#
# company  8 Texas A&M University System
#
# company  9 iHeartMedia
#
# company  10 University of Wisconsin-Madison
#
# company  11 PARC, a Xerox Company
#
# company  12 The Johns Hopkins University Applied Physics Laboratory
#
# company  13 CES
#
# company  14 Collabera Inc.
#
# company  15 The New York Times
#
# company  16 Wayfair
#
# company  17 Guild Education
#
# company  18 FrameWorks Institute
#
# company  19 Vicarious AI
#
# company  20 Case Western Reserve University
#
# company  21 The Penn State Student Radio Alumni Interest Group
#
# company  22 US Department of Agriculture (USDA) Agricultural Research Service (ARS)
#
# company  23 Madison Metropolitan School District
#
# company  24 U.S. Bank
#
# Cambridge, Massachusetts
# Pensacola, Florida Area
# Arlington, VA, US
# New York City, NY, US
# New York City, NY, US
# San Jose, CA, US
# San Francisco, CA, US
# New York City, NY, US
# Prairie View, TX, US
# New York County, NY, US
# Madison, WI, US
# Palo Alto, CA, US
# Laurel, MD, US
# Williston, North Dakota
# Mountain View, CA, US
# New York City, NY, US
# Boston, MA, US
# Denver, CO, US
# Washington, D.C., DC, US
# Union City, CA, US
# Cleveland, OH, US
# University Park, FL, US
# Mayaguez, Puerto Rico, Puerto Rico
# Madison, WI, US
# Earth City, Missouri
# 0
# https://www.linkedin.com/jobs/view/researcher-at-commonwealth-sciences-inc-1345659388?position=1&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 1
# https://www.linkedin.com/jobs/view/researcher-at-ims-expertservices-1407600852?position=2&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 2
# https://www.linkedin.com/jobs/view/researcher-communication-research-at-fors-marsh-group-1367809632?position=3&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 3
# https://www.linkedin.com/jobs/view/researcher-at-forrester-1417506786?position=4&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 4
# https://www.linkedin.com/jobs/view/researcher-at-lancesoft-inc-1330441223?position=5&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 5
# https://www.linkedin.com/jobs/view/researcher-at-rose-international-1342759413?position=6&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 6
# https://www.linkedin.com/jobs/view/researcher-at-nextdoor-1412111280?position=7&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 7
# https://www.linkedin.com/jobs/view/ux-researcher-research-assistant-at-intellipro-group-inc-1389707730?position=8&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 8
# https://www.linkedin.com/jobs/view/postdoctoral-researcher-research-administration-at-texas-a-m-university-system-1375261027?position=9&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
# 9
# https://www.linkedin.com/jobs/view/researcher-at-iheartmedia-1407610708?position=10&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
#
#
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
def add_full_desc(df):
    
    'Extracts full linkedin post info and adds to 5 columns to existing dataframe for city/role'
    
    full_job_desc = []
    seniority_level = []
    employment_type = []
    job_function = []
    industries = []
            
    # iterates over list of urls from urls column in df
    for index, row in df.iterrows():
        soup = get_names(row[5])
                
        '''Extracting job post body'''
        info = get_linkedin_info(soup)
        #full_job_desc.append(info['full_desc'])
                    
        if 'Seniority level' in info.keys():
            seniority_level.append(info['Seniority level'])
        else:
            seniority_level.append('NA')
                
        if 'Employment type' in info.keys():
            employment_type.append(info['Employment type'])
        else:
            employment_type.append('NA')
                
        if 'Job function' in info.keys():
            job_function.append(info['Job function'])

        else:
            job_function.append('NA')
                
        if 'Industries' in info.keys():
            industries.append(info['Industries'])
        else:
            industries.append('NA')
                
    #df['full_desc'] = full_job_desc
    #df['seniority_level']= seniority_level
    #df['employment_type']= employment_type
    #df['job_function']= job_function
    #df['industries']= industries
    
    return df

# %%
# CHANGE TO REGEX SEARCH INSTEAD 
# WITH TRY EXCEPT ERROR https://stackoverflow.com/questions/4666973/how-to-extract-the-substring-between-two-markers

# %%
def get_linkedin_info(soup):
    
    "takes soup object and turns into LinkedIn full description"
    
    additional_info = {}
    full_desc = ''
    
    try:
        soup.find_all("div", {"class": "description__text"})
        
        
    except NoneType:
        full_desc = 'NA'
    else:
        for item in soup.find_all("div", {"class": "description__text"}):
            full_desc = full_desc + item.text
            full_desc = full_desc + ' \n'
    
    print(full_desc)
    additional_info['full_desc'] = full_desc

    

    '''
    if soup.find_all('p')is None:
        full_desc = 'NA'
        
    else:
        for item in soup.find_all("div", {"class": "description__text"}):
            full_desc = full_desc + item.text
            full_desc = full_desc + ' \n'
    
    '''
    
    '''Extracting Additional Categories from LinkedIn Post'''
    
    try:
        
        for item in soup.find_all('h3', attrs={'class': 'job-criteria__subheader'}):
            
            
            '''Make a library with the key names as the category (ie seniority level, industry, job functions, employment type)'''
            additional_info[item.text] = item.next_sibling.text


            item2 = item.next_sibling
            while item2.next_sibling is not None:
                additional_info[item.text] = additional_info[item.text] + ', ' + item2.next_sibling.text
                #print(additional_info[item])
                item2 = item2.next_sibling
            #print()

    except NoneType:
        pass
        
    return additional_info

# %%
# help? https://stackoverflow.com/questions/19595296/whats-the-correct-try-exception-for-nonetype-when-using-regexs-groups-funct

# %%
if __name__ == '__main__':

    cities = ['San Francisco, California',
              'New York, New York']
    '''
              'Seattle, Washington',
              'Washington, DC',
              'Chicago, Illinois',
              'Atlanta, Georgia',
              'Portland, Oregon',
              'Honolulu, Hawaii']
              '''
    
    '''
    roles = ['Data Scientist',
    'Data Analyst',
    'Business Analyst',
    'Business Intelligence',
    'Data Engineer',
    'Machine Learning Engineer',
    'Machine Learning Scientist',
    'Artificial Intelligence Researcher',
    'Statistical Modeler']'''
    
    roles = ['Researcher']
    
    
    
    df_main = pd.DataFrame()
    for role in roles:
        for city in cities:        
            url =get_url(city, role)
            print(url)
            soup = get_names(url)
            df = get_divs(soup)
            #df['role'] = [role for value in df.iterrows()]

            df['role'] = len(df.index)*[role]
            
            
            df = add_full_desc(df)
            
            frames = [df_main, df]
            result = pd.concat(frames)
            df_main = result
            print(df_main.shape)

    datetime.now().month, datetime.now().day
# Out:
# https://www.linkedin.com/jobs/search?keywords=Researcher&location=San%20Francisco%2C%20California%2C%20United%20States&trk=homepage-basic_jobs-search-bar_search-submit&redirect=false&position=1&pageNum=0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Error during requests to Researcher : Invalid URL 'Researcher': No schema supplied. Perhaps you meant http://Researcher?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-87182b58308d> in get_linkedin_info(soup)
#       8     try:
# ----> 9         soup.find_all("div", {"class": "description__text"})
#      10
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-051e819e2407> in <module>
#      39
#      40
# ---> 41             df = add_full_desc(df)
#      42
#      43             frames = [df_main, df]
#
# <ipython-input-8-e905598fa531> in add_full_desc(df)
#      14
#      15         '''Extracting job post body'''
# ---> 16         info = get_linkedin_info(soup)
#      17         #full_job_desc.append(info['full_desc'])
#      18
#
# <ipython-input-13-87182b58308d> in get_linkedin_info(soup)
#      10
#      11
# ---> 12     except NoneType:
#      13         full_desc = 'NA'
#      14     else:
#
# NameError: name 'NoneType' is not defined

# %%
df
# Out:
#                                         company  \
# 0                             Avispa Technology
# 1                          Wikimedia Foundation
# 2                               LanceSoft, Inc.
# 3                   Motion Recruitment Partners
# 4                                     Forrester
# 5                                           IBM
# 6                        HR Multinational Corp.
# 7                                   iHeartMedia
# 8                          Intellipro Group Inc
# 9                                          BAMM
# 10                      CBS Television Stations
# 11                           The New York Times
# 12                               Temujin Studio
# 13                               The New School
# 14                                   VelvetJobs
# 15                                       Comeet
# 16                                Freedom House
# 17                             Stanley Brothers
# 18                  New York State Nurses Assoc
# 19                                           GE
# 20        Teachers College, Columbia University
# 21                                  Cypress HCM
# 22                           NYU Langone Health
# 23                  Physicians for Human Rights
# 24  Columbia University in the City of New York
#
#                               location  \
# 0                   New York, New York
# 1                   New York, New York
# 2                New York City, NY, US
# 3                New York City, NY, US
# 4                New York City, NY, US
# 5                New York City, NY, US
# 6                     Brooklyn, NY, US
# 7              New York County, NY, US
# 8                New York City, NY, US
# 9   Manhattan, New York, United States
# 10               New York City, NY, US
# 11               New York City, NY, US
# 12               New York City, NY, US
# 13               New York City, NY, US
# 14               New York City, NY, US
# 15               New York City, NY, US
# 16               New York City, NY, US
# 17    Buffalo, New York, United States
# 18               New York City, NY, US
# 19                   Niskayuna, NY, US
# 20               New York City, NY, US
# 21                  New York, New York
# 22               New York City, NY, US
# 23               New York City, NY, US
# 24               New York City, NY, US
#
#                                           title   post_date  \
# 0                          UX/Design Researcher  2019-07-31
# 1           Senior Design Researcher, Languages  2019-08-02
# 2                             Design Researcher  2019-06-17
# 3                             Design Researcher  2019-05-03
# 4                                    Researcher  2019-08-07
# 5               Entry Level - Design Researcher  2019-07-25
# 6                                    RESEARCHER  2019-08-04
# 7                                    Researcher  2019-07-08
# 8            UX Researcher (Research Assistant)  2019-07-23
# 9         Ethnographer / Qualitative Researcher  2019-07-18
# 10                                   Researcher  2019-07-27
# 11                                   Researcher  2019-02-20
# 12                                   Researcher  2019-07-04
# 7                      Jobs Interviewing Now from MJH
# 8                                   The Oakleaf Group
# 9                                                 BRP
# 10                            Capital Insurance Group
# 11                                Booz Allen Hamilton
# 12                                      T. Rowe Price
# 13                              The Third Floor, Inc.
# 14                                              Roush
# 15                                                UBS
# 16                                   Wasatch Electric
# 17                               Jobs @ TheJobNetwork
# 18                               University of Denver
# 19                                              ALTEN
# 20                    Pinnacle Solutions Incorporated
# 21                 Ezra Penland Actuarial Recruitment
# 22                           Northern Metal Fab, Inc.
# 23                      Texas Water Development Board
# 24                                               Juul
#
#                       location  \
# 0   South Pasadena, California
# 1                Omaha, NE, US
# 2               Skokie, IL, US
# 3                Omaha, NE, US
# 4              Atlanta, GA, US
# 5     Washington, D.C., DC, US
# 6     Washington, D.C., DC, US
# 7          Minneapolis, MN, US
# 8     Washington, D.C., DC, US
# 9               Stuart, FL, US
# 10            Monterey, CA, US
# 11            Columbia, MD, US
# 12           Baltimore, MD, US
# 13         Los Angeles, CA, US
# 14             Livonia, MI, US
# 15       New York City, NY, US
# 16      Salt Lake City, UT, US
# 17              Laurel, MD, US
# 18              Denver, CO, US
# 19  Greensboro, North Carolina
# 20             Detroit, MI, US
# 21          Cincinnati, OH, US
# 22             Baldwin, WI, US
# 23              Austin, TX, US
# 24       San Francisco, CA, US
#
#                                                 title   post_date  \
# 0                                     Digital Modeler  2019-08-01
# 1                                 Statistical Modeler  2019-07-27
# 2                          Senior Statistical Modeler  2019-08-02
# 3                                 Statistical Modeler  2019-08-04
# 4                    Mathematical/Statistical Modeler  2019-06-21
# 5                      Quantitative Analyst/Modeler 4  2019-08-02
# 6                      Quantitative Analyst/Modeler 4  2019-07-31
# 7                    Statistical Modeler - RELX Group  2019-07-28
# 8                              Quantitative Modeler I  2019-04-27
# 9                                     Digital Modeler  2019-05-03
# 10                                 Predictive Modeler  2019-01-31
# 11                               Mathematical Modeler  2019-07-31
# 12                                  Portfolio Modeler  2018-12-01
# 13                                   Previs - Modeler  2019-04-23
# 14                                        CAE Modeler  2019-06-25
# 15                                       PPNR Modeler  2019-06-20
# 16                       Modeler Designer - UT5012053  2019-07-08
# 17                       Acoustic Modeler and Analyst  2019-08-05
# 18                               Quantitative Modeler  2019-06-12
# 19  Digital Surface Modeler/Class-A Modeler/Alias ...  2019-08-05
# 20            SAS Advanced Analytics Analyst -Modeler  2019-06-27
# 21   Catastrophe Modeler and Risk Analytics Pro 86071  2019-08-04
# 22                                 SolidWorks Modeler  2018-11-18
# 23                      Hydrodynamic Modeler/Engineer  2018-11-18
# 24                                   Aerosols Modeler  2019-07-31
#
#                                           description  \
# 0   Geely Design is currently looking for a Senior...
# 1   Experience in marketing analysis related to di...
# 2   Experience in applying statistical techniques ...
# 3   Experience in marketing analysis related to di...
# 4   What You Will Do. Strong experience performing...
# 5   The estimate of potential mitigation could inv...
# 6   BS in relevant discipline with 8+ yrs relevant...
# 7   With over 40 years of expertise, we are the tr...
# 8   In this position the ideal candidate will work...
# 9   You are looking for an exciting job where you ...
# 10  Capital Insurance Group is seeking a candidate...
# 11  You’ll have access to a wealth of training res...
# 12  We believe our associates are the key to this ...
# 13  Here is a guide to help understand what TTF is...
# 14  Are you a CAE Modeler looking for a dynamic co...
# 15  If so then you we are looking for you to: Do y...
# 16  We offer our employees a competitive salary an...
# 17  Benefits: APL offers a comprehensive benefits ...
# 18  Although no modeler is likely to have pre-exis...
# 19  Role: This position is responsible for creatin...
# 20  Pinnacle Solutions, Inc. is seeking a highly e...
# 21  Must have 5+ years of catastrophe modeling exp...
# 22  Familiarity or experience with sheet metal fab...
# 23  ENG10 Engineering) or other related fields per...
# 24  JUUL's mission is to improve the lives of the ...
#
#                                                   url                 role
# 0   https://www.linkedin.com/jobs/view/digital-mod...  Statistical Modeler
# 1   https://www.linkedin.com/jobs/view/statistical...  Statistical Modeler
# 2   https://www.linkedin.com/jobs/view/senior-stat...  Statistical Modeler
# 3   https://www.linkedin.com/jobs/view/statistical...  Statistical Modeler
# 4   https://www.linkedin.com/jobs/view/mathematica...  Statistical Modeler
# 5   https://www.linkedin.com/jobs/view/quantitativ...  Statistical Modeler
# 6   https://www.linkedin.com/jobs/view/quantitativ...  Statistical Modeler
# 7   https://www.linkedin.com/jobs/view/statistical...  Statistical Modeler
# 8   https://www.linkedin.com/jobs/view/quantitativ...  Statistical Modeler
# 9   https://www.linkedin.com/jobs/view/digital-mod...  Statistical Modeler
# 10  https://www.linkedin.com/jobs/view/predictive-...  Statistical Modeler
# 11  https://www.linkedin.com/jobs/view/mathematica...  Statistical Modeler
# 12  https://www.linkedin.com/jobs/view/portfolio-m...  Statistical Modeler
# 13  https://www.linkedin.com/jobs/view/previs-mode...  Statistical Modeler
# 14  https://www.linkedin.com/jobs/view/cae-modeler...  Statistical Modeler
# 15  https://www.linkedin.com/jobs/view/ppnr-modele...  Statistical Modeler
# 16  https://www.linkedin.com/jobs/view/modeler-des...  Statistical Modeler
# 17  https://www.linkedin.com/jobs/view/acoustic-mo...  Statistical Modeler
# 18  https://www.linkedin.com/jobs/view/quantitativ...  Statistical Modeler
# 19  https://www.linkedin.com/jobs/view/digital-sur...  Statistical Modeler
# 20  https://www.linkedin.com/jobs/view/sas-advance...  Statistical Modeler
# 21  https://www.linkedin.com/jobs/view/catastrophe...  Statistical Modeler
# 22  https://www.linkedin.com/jobs/view/solidworks-...  Statistical Modeler
# 23  https://www.linkedin.com/jobs/view/hydrodynami...  Statistical Modeler
# 24  https://www.linkedin.com/jobs/view/aerosols-mo...  Statistical Modeler

# %%
# Example Test
for key, item in df.iloc[0, :].iteritems():
    print(key, ': ', item)
# Out:
# company :  Sterling National Bank
# location :  Yonkers, New York
# title :  Risk Modeler
# post_date :  2019-07-15
# description :  Sterling National Bank is looking for a Risk Modeler for the organization’s Model Risk Management Division. Experience in Financial ...
# url :  https://www.linkedin.com/jobs/view/risk-modeler-at-sterling-national-bank-1333834289?position=1&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click
# full_desc :  Sterling National Bank is looking for a Risk Modeler for the organization’s Model Risk Management Division.  In this position:     You will ensure and monitor compliance with regulatory requirements and guidance as well as the bank’s Model Risk policy and procedures. You will work on various functions including model inventory management, model validation, model monitoring, model risk assessment, model risk reporting, and compliance support.     Very Strong Compensation (up to $105,000)  PLUS Profit Sharing, 401k, Plus Benefits, up to $300,000 of free life insurance, Free Masters Education Reimbursement available,  and enjoy WORKING FROM HOME 2-3 days a week!     **All candidates must be US Citizen or Green Card only     JOB RESPONSIBILITIES  Core Job Responsibilities/Key Activities/Elements:  2.           Model monitoring and change management  3.           Assist in managing the model validation process  4.           Model issues follow up and resolution.  5.           Risk management of the non-model tools  6.           Model risk reporting and compliance support     Experience in Financial Services in the areas of RISK and Modeling tools (R, SAS, OR  Python) Required.     Sterling National Bank is on Forbes’ list of Best Banks in America.     What do WE bring to the table?     Sterling offers you a chance to grow your career and offers you the ability to move into other areas of banking as you go. We promote from within and take pride in the fact that people actually DON'T MIND coming to work; it's a very comfortable environment with lots of flexibility-- And you can work from Home!    If you are interested and qualified we can set-up an interview at your convenience.
#
# seniority_level :  Associate
# employment_type :  Full-time
# job_function :  Other
# industries :  Banking

# %%
df
# Out:
#                                company               location  \
# 0               Sterling National Bank      Yonkers, New York
# 1                         Bloomberg LP  New York City, NY, US
# 2                                  UBS  New York City, NY, US
# 3                    eFinancialCareers  New York City, NY, US
# 4                               FJA-US  New York City, NY, US
# 5                 Jobs @ TheJobNetwork  New York City, NY, US
# 6                      Alliant-insight       Brewster, NY, US
# 7            Fortress Investment Group     New York, New York
# 8            Michael Bailey Associates        Kingdom, NY, US
# 9                                  FJA  New York City, NY, US
# 10                            Fortress  New York City, NY, US
# 11                Cosentini Associates  New York City, NY, US
# 12                     Bank of America  New York City, NY, US
# 13                                 LCH  New York City, NY, US
# 14  London Stock Exchange Group (LSEG)     New York, New York
# 15                         CyberCoders  New York City, NY, US
# 16                          VelvetJobs  New York City, NY, US
# 17                      Morgan Stanley  New York City, NY, US
# 18                    Pryor Associates       Brooklyn, NY, US
# 19                Jobs @ TheJobNetwork  New York City, NY, US
# 20                   eFinancialCareers  New York City, NY, US
# 21                 VBeyond Corporation  New York City, NY, US
# 22                    Pryor Associates       Brooklyn, NY, US
# 23                    Pryor Associates       Brooklyn, NY, US
# 24                         CyberCoders  New York City, NY, US
#
#                                                 title   post_date  \
# 0                                        Risk Modeler  2019-07-15
# 1                         Structured Products Modeler  2019-08-05
# 2                                        PPNR Modeler  2019-06-20
# 3                                         MBS modeler  2019-07-12
# 4            Product Analyst/modeler, Group Insurance  2019-07-30
# 5                          Structured Finance Modeler  2019-08-02
# 6                                  Predictive Modeler  2019-07-10
# 7                        Predictive Analytics Modeler  2019-08-02
# 8                        Energy / Powersystem modeler  2019-07-15
# 9   Product Analyst/Modeler, Group Insurance - New...  2019-08-04
# 10                       Predictive Analytics Modeler  2019-08-04
# 11                                  Revit MEP Modeler  2018-11-18
# 12                        Consumer Behavior Modeler I  2019-07-29
# 13                                Agency CMBS Modeler  2019-07-24
# 7   Financial Services, Investment Management, Rea...
# 8   Information Technology and Services, Computer ...
# 9   Information Technology and Services, Computer ...
# 10  Banking, Financial Services, Investment Manage...
# 11  Architecture & Planning, Civil Engineering, Me...
# 12  Information Technology and Services, Banking, ...
# 13  Marketing and Advertising, Information Technol...
# 14  Financial Services, Information Technology and...
# 15  Construction, Information Technology and Servi...
# 16                                 Financial Services
# 17  Financial Services, Investment Banking, Invest...
# 18  Information Technology and Services, Insurance...
# 19                                 Financial Services
# 20                            Staffing and Recruiting
# 21  Information Technology and Services, Computer ...
# 22  Information Technology and Services, Insurance...
# 23  Information Technology and Services, Insurance...
# 24                            Architecture & Planning

# %%
soup = get_names(url)

# %%
type(soup)
# Out:
# NoneType

# %%
df.iloc[2,5]
# Out:
# 'https://www.linkedin.com/jobs/view/data-analyst-at-sibitalent-corp-1405371759?position=3&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click'

# %%
url2 = 'https://www.linkedin.com/jobs/view/data-analyst-at-sibitalent-corp-1405371759?position=3&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click'

soup2 = get_names(url2)
#df2 = get_divs(soup2)
info2 = get_linkedin_info(soup2)

# %%
type(info2)
# Out:
# dict

# %%
url = 'https://www.linkedin.com/jobs/search?keywords=Machine%20Learning%20Scientist&location=Honolulu%2C%20Hawaii%2C%20United%20States&trk=homepage-basic_jobs-search-bar_search-submit&redirect=false&position=1&pageNum=0'

soup = get_names(url)
df=get_divs(soup)
#info = het_linked_info(soup)

# %%
for item in soup.find_all('h4', attrs={'class': 'result-card__subtitle job-result-card__subtitle'}):
    print(item.text)
# Out:
# ClearedJobs.Net
# OneinaMil, LLC
# Booz Allen Hamilton
# Precision Solutions, LLC
# Precision Solutions, Inc.
# ClearanceJobs
# Booz Allen Hamilton
# ClearedJobs.Net
# ClearanceJobs

# %%
df_main.shape
# Out:
# (143, 11)

# %%
test_url = df.iloc[0, 5]

# %%
df = get_divs(soup)

# %%
df.head()
# Out:
#                      company                           location  \
# 0                  Patch.com                 New York, New York
# 1            Infosys Limited                 New York, New York
# 2  KGS Technology Group, Inc  New York, New York, United States
# 3       Jobs @ TheJobNetwork              New York City, NY, US
# 4   Barclays Investment Bank                   Whippany, NJ, US
#
#                                             title   post_date  \
# 0                                    Data Analyst  2019-07-22
# 1                                    Data Analyst  2019-07-23
# 2                                    Data Analyst  2019-06-28
# 3  Senior Data Operations Analyst, Data Analytics  2019-07-26
# 4                                    Data Analyst  2019-06-25
#
#                                          description  \
# 0  Patch is seeking a motivated and meticulous da...
# 1  Desired Skills & Experience.           Experie...
# 2  We are looking for a passionate Data Analyst t...
# 3  Some knowledge of advanced statistical techniq...
# 4  What will you be doing? What We’re Looking For...
#
#                                                  url
# 0  https://www.linkedin.com/jobs/view/data-analys...
# 1  https://www.linkedin.com/jobs/view/data-analys...
# 2  https://www.linkedin.com/jobs/view/data-analys...
# 3  https://www.linkedin.com/jobs/view/senior-data...
# 4  https://www.linkedin.com/jobs/view/data-analys...

# %%
url
soup = get_names(url)

# %%
url
# Out:
# 'https://www.linkedin.com/jobs/search?keywords=Data%20Analyst&location=%2C%20York%2C%20United%20States&trk=homepage-basic_jobs-search-bar_search-submit&redirect=false&position=1&pageNum=0'
