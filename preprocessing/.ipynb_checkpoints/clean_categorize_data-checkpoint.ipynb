# %%
import glob
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ### Merge separate data files into one data frame `(df_main)`

# %%
df_master = pd.DataFrame()

files = glob.glob('../data_raw/*.csv')
files
# Out:
# ['../data_raw/indeed-8-5.csv',
#  '../data_raw/indeed-8-7.csv',
#  '../data_raw/linkedin-8-5.csv',
#  '../data_raw/linkedin-8-9.csv',
#  '../data_raw/linkedin-8-8.csv',
#  '../data_raw/indeed-8-8.csv',
#  '../data_raw/indeed-8-9.csv']

# %%
for i, filepath in enumerate(files):
    df = pd.read_csv(filepath, encoding='latin1')
    filename_elements = filepath.split('/')[2].split('.')[0].split('-')  # splits up the filename to extract platform & search date info
    df['platform'] = filename_elements[0]  # first element is the platform
    df['search_date'] = f'{filename_elements[1]}-{filename_elements[2]}-2019'  # second/third elements are the month & date of the search
    
    frames = [df_master, df]
    df_master = pd.concat(frames, sort=True)

# %%
df_master = df_master.dropna(subset=['description'])  # Drop rows with null values in description
df_master.head(20)
# Out:
#                           company  \
# 0                       Noom Inc.
# 1   Strategic Financial Solutions
# 2                         Averity
# 3               Lenmar Consulting
# 4        Memorial Sloan Kettering
# 5                      Digitalogy
# 6                          Viacom
# 7               Butterfly Network
# 8                         Celonis
# 9                          Macy's
# 10                    Squarespace
# 11     Remedy BPCI Partners, LLC.
# 12                   Getty Images
# 13                Remedy Partners
# 14                      Quantilus
# 15                       TRANZACT
# 16                           81qd
# 17                          Apple
# 18                      eBay Inc.
# 19                  Akvelon, Inc.
#
#                                           description employment_type  \
# 0    \n At Noom, we use scientifically proven meth...             NaN
# 1    \n Overview\nDo you love numbers and finding ...             NaN
# 2    \n We are one of the world's premiere travel ...             NaN
# 3    \n Medical Data Scientist \n Must have at lea...             NaN
# 4    \n <h2 class="jobSectionHeader">Company Overv...             NaN
# 5    \n What you will do\n\nResponsible for assist...             NaN
# 6    \n <h2 class="jobSectionHeader">Overview and ...             NaN
# 7    \n Job Description<br/>\n<br/>\nWe are lookin...             NaN
# 8    \n Are you ready for a new challenge?\n \n <b...             NaN
# 9    \n Job Overview:<br/>\n\n\nAs part of the Sup...             NaN
# 10   \n Customer Operations Data Scientists formul...             NaN
# 11   \n This role will report to our VP, Data Scie...             NaN
# 12   \n Who You Are:\nGetty Images is looking for ...             NaN
# 13   \n <h3 class="jobSectionHeader">Description\n...             NaN
# 14   \n  \n JOTITLE: Data Analyst/Data Scientist\n...             NaN
# 15   \n How the Position Works \n The Data Scienti...             NaN
# 16   \n 81qd â Data Scientist Intern \n 81qd is ...             NaN
# 17   \n Summary\nPosted: Jun 30, 2019\nWeekly Hour...             NaN
# 18   \n Looking for a company that inspires passio...             NaN
# 19   \n Our client is an Amazing company in Redmon...             NaN
#
#    full_desc industries job_function            location platform post_date  \
# 0        NaN        NaN          NaN        New York, NY   indeed       30+
# 1        NaN        NaN          NaN  New York, NY 10018   indeed        18
# 2        NaN        NaN          NaN        New York, NY   indeed        12
# 3        NaN        NaN          NaN  Woodcliff Lake, NJ   indeed         0
# 4        NaN        NaN          NaN  New York, NY 10017   indeed        16
# 5        NaN        NaN          NaN        New York, NY   indeed         5
# 6        NaN        NaN          NaN  New York, NY 10036   indeed         7
# 7        NaN        NaN          NaN        New York, NY   indeed         3
# 8        NaN        NaN          NaN  New York, NY 10036   indeed         2
# 9        NaN        NaN          NaN  New York, NY 10001   indeed        14
# 10       NaN        NaN          NaN  New York, NY 10014   indeed        10
# 11       NaN        NaN          NaN        New York, NY   indeed         4
# 12       NaN        NaN          NaN        New York, NY   indeed        15
# 13       NaN        NaN          NaN        New York, NY   indeed         5
# 14       NaN        NaN          NaN  New York, NY 10036   indeed         3
# 15       NaN        NaN          NaN  Fort Lee, NJ 07024   indeed       30+
# 16       NaN        NaN          NaN  New York, NY 10017   indeed         4
# 17       NaN        NaN          NaN         Seattle, WA   indeed       30+
# 18       NaN        NaN          NaN  Bellevue, WA 98009   indeed       30+
# 19       NaN        NaN          NaN         Redmond, WA   indeed        11
#
#                         salary search_city search_date     search_role  \
# 0                          NaN         NaN    8-5-2019  Data Scientist
# 1                          NaN         NaN    8-5-2019  Data Scientist
# 2   $175,000 - $225,000 a year         NaN    8-5-2019  Data Scientist
# 3                  $75 an hour         NaN    8-5-2019  Data Scientist
# 4                          NaN         NaN    8-5-2019  Data Scientist
# 5            $50 - $80 an hour         NaN    8-5-2019  Data Scientist
# 6                          NaN         NaN    8-5-2019  Data Scientist
# 7                          NaN         NaN    8-5-2019  Data Scientist
# 8                          NaN         NaN    8-5-2019  Data Scientist
# 9                          NaN         NaN    8-5-2019  Data Scientist
# 10                         NaN         NaN    8-5-2019  Data Scientist
# 11                         NaN         NaN    8-5-2019  Data Scientist
# 12                         NaN         NaN    8-5-2019  Data Scientist
# 13                         NaN         NaN    8-5-2019  Data Scientist
# 14                         NaN         NaN    8-5-2019  Data Scientist
# 15                         NaN         NaN    8-5-2019  Data Scientist
# 16                         NaN         NaN    8-5-2019  Data Scientist
# 17                         NaN         NaN    8-5-2019  Data Scientist
# 18                         NaN         NaN    8-5-2019  Data Scientist
# 19                         NaN         NaN    8-5-2019  Data Scientist
#
#    seniority_level                                              title  \
# 0              NaN                                     Data Engineer
# 1              NaN                               Lead Data Scientist
# 2              NaN                             Manager, Data Science
# 3              NaN                            Medical Data Scientist
# 4              NaN  Sr Strategic Consultant / Data Scientist (Pati...
# 5              NaN                                    Data Scientist
# 6              NaN                                Jr. Data Scientist
# 7              NaN                                    Data Scientist
# 8              NaN                                    Data Scientist
# 9              NaN                          Associate Data Scientist
# 10             NaN               Data Scientist, Customer Operations
# 11             NaN                             Junior Data Scientist
# 12             NaN                                    Data Scientist
# 13             NaN                             Junior Data Scientist
# 14             NaN                       Data Analyst/Data Scientist
# 15             NaN                             Senior Data Scientist
# 16             NaN                             Data Scientist Intern
# 17             NaN               Machine Learning Research Scientist
# 18             NaN                                    Data Scientist
# 19             NaN                                     Data Scientist
#
#                                                   url
# 0   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 5   https://www.indeed.com/rc/clk?jk=83e3f665b22e5...
# 6   https://www.indeed.com/rc/clk?jk=1942a17d2bd16...
# 7   https://www.indeed.com/rc/clk?jk=14bc4e97c18a1...
# 8   https://www.indeed.com/rc/clk?jk=755c879e19b03...
# 9   https://www.indeed.com/rc/clk?jk=126152117b65e...
# 10  https://www.indeed.com/rc/clk?jk=8adad16880a99...
# 11  https://www.indeed.com/rc/clk?jk=d19b36ecfcd4b...
# 12  https://www.indeed.com/rc/clk?jk=496954e681172...
# 13  https://www.indeed.com/rc/clk?jk=2646d9747e37d...
# 14  https://www.indeed.com/rc/clk?jk=b2def2428396b...
# 15  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 16  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 17  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 18  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 19  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...

# %% [markdown]
# ### Observations
# - Inconsistency in which features are included. There are many null values throughout the data
# - Very inconsistent/sparse salary column

# %% [markdown]
# ### Save master data frame

# %%
df_subset = df_master[['company', 'description', 'location', 'title', 'url']]
df_subset.to_csv("../data_processed/concatenated_data.csv", index=False)

# %% [markdown]
# ### Group job titles into categories

# %%
all_job_titles = list(df_master['title'].unique())

# data scientists
data_scientist_count = 0

# engineers
data_engineer_count = 0
machine_learning_engineer_count = 0

# analysts
data_analyst_count = 0
business_analyst_count = 0

# research
ml_ai_research_count = 0
statistics_count = 0

job_title_dictionary = {}

for job_title in all_job_titles:
    if 'data' in job_title.lower() and 'scien' in job_title.lower():
        job_title_dictionary[job_title] = ['Data Scientist']
        data_scientist_count += 1
    if 'data' in job_title.lower() and 'engineer' in job_title.lower():
        data_engineer_count += 1
        if job_title in job_title_dictionary.keys():  # if the job title has already been given one of the previous labels, add on to it
            labels = job_title_dictionary[job_title]
            labels.append('Data Engineer')
            job_title_dictionary[job_title] = labels
        else:
            job_title_dictionary[job_title] = ['Data Engineer']
    if ('machine learning' in job_title.lower() or 'ml' in job_title.lower())\
        and ('engineer' in job_title.lower() or 'developer' in job_title.lower() or 'software' in job_title.lower()):
        machine_learning_engineer_count += 1
        if job_title in job_title_dictionary.keys():  # if the job title has already been given one of the previous labels, add on to it
            labels = job_title_dictionary[job_title]
            labels.append('Machine Learning Engineer')
            job_title_dictionary[job_title] = labels
        else:
            job_title_dictionary[job_title] = ['Machine Learning Engineer']
    if 'analy' in job_title.lower() and 'data' in job_title.lower():
        data_analyst_count += 1
        if job_title in job_title_dictionary.keys():  # if the job title has already been given one of the previous labels, add on to it
            labels = job_title_dictionary[job_title]
            labels.append('Data Analyst')
            job_title_dictionary[job_title] = labels
        else:
            job_title_dictionary[job_title] = ['Data Analyst']
    if ('analy' in job_title.lower() or 'intelli' in job_title.lower()) and ('business' in job_title.lower() or 'product' in job_title.lower()\
        or 'market' in job_title.lower() or 'strategy' in job_title.lower() or 'management' in job_title.lower()):
        business_analyst_count += 1
        if job_title in job_title_dictionary.keys():  # if the job title has already been given one of the previous labels, add on to it
            labels = job_title_dictionary[job_title]
            labels.append('Business Analyst')
            job_title_dictionary[job_title] = labels
        else:
            job_title_dictionary[job_title] = ['Business Analyst']
    if 'research' in job_title.lower() and ('machine learning' in job_title.lower() or 'ml' in job_title.lower()\
        or 'ai' in job_title.lower() or 'artificial intelligence' in job_title.lower()):
        ml_ai_research_count += 1
        if job_title in job_title_dictionary.keys():  # if the job title has already been given one of the previous labels, add on to it
            labels = job_title_dictionary[job_title]
            labels.append('ML/AI Researcher')
            job_title_dictionary[job_title] = labels
        else:
            job_title_dictionary[job_title] = ['ML/AI Researcher']
    if 'statistic' in job_title.lower() and ('model' in job_title.lower() or 'research' in job_title.lower()):
        statistics_count += 1
        if job_title in job_title_dictionary.keys():  # if the job title has already been given one of the previous labels, add on to it
            labels = job_title_dictionary[job_title]
            labels.append('Statistical Modeler/Researcher')
            job_title_dictionary[job_title] = labels
        else:
            job_title_dictionary[job_title] = ['Statistical Modeler/Researcher']

with open('job_title_dictionary.json', 'w') as json_file:
    json.dump(job_title_dictionary, json_file)

# %%
count = 0
for job_title in all_job_titles:
    if job_title not in job_title_dictionary.keys():
        count += 1
        print(job_title)
count
# Out:
# Software Engineer
# decision scientist, Applied Analytics
# Siri
# Graduate Studies Program
# Mid
# Federal
# Artificial Intelligence Specialist
# Data Architect
# Quantitative Finance Analyst
# Senior Biostatistician, Cardiology Projects
# Biologist/Water Resources Scientist
# Health Actuary
# Systems Administrator
# Machine Learning & AI Architect
# Machine Learning GRA
# ACG
# Annotation Operations
# Deep Learning Innovation Engineer
# ADAS Engineer
# Security Engineer
# Field Service Engineer
# Cloud Data Architect
# PROJECT CONTROLS MANAGER / ENGINEER
# PROJECT MANAGER
# ENGINEER III
# Technical Lead
# Innovative AI/ML Technical Lead
# Machine Learning Scientist, Digital & Computational Pathology
# Machine Learning /NLP
# Research Scientist
# Sr. Machine Learning Scientist
# Platform Architect
# Mathematical Statistician
# Senior Artificial Intelligence / Machine Learning Scientist
# Scientist
# Machine Learning Scientist, Platforms
# Mathematician
# Senior Manager, Machine Learning Scientist
# Sr. Manager Machine Learning Scientist, Anomaly Detection
# Staff Scientist
# Director of Innovation Programs, NSRL
# Content Specialist
# Computational Researcher
# Research Intern
# Research Intern
# Visiting Scientist (AI)
# Associate Research Manager
# Writer/Editor
# Full Time Opportunities for PhD Students or Recent Graduates: Researcher
# Internship Opportunities for PhD Students: Researcher
# Researcher
# High Performance Computing Software Researcher
# Director, Brooks Runner Performance Lab
# Associate Director
# Motor Neurophysiology Post
# Operations Research Analyst (Mid
# Artificial General Intelligence Researcher
# Research Analyst, CUSE (Job ID: 2019
# Head of Policy, Digital Innovation and Democracy Initiative
# Staff Researcher (3 opportunities)
# Senior Manager, Natural Language Processing Research
# Robotics Researcher Post
# Cyber Security Researcher
# Accenture Labs
# Senior Motor Neurophysiology Researcher
# Sr. UX Designer
# Molecular Research Associate
# Synthetic Biologist
# Researcher in Residence (NA Innovation Hub)*
# Lead Machine Learning Analyst
# Experienced Quantitative Portfolio Manager or Strategist 1H2017
# BIM Manager
# Division Chief, Cybersecurity
# Director, Client Success
# Principal Artificial Intelligence Systems Engineer
# Power Management Software Engineer and Researcher
# PPNR Modeler
# Mortgage Prepayment Modeling Strategist/Modeler
# Quantitative Asset Modeler
# Associate
# Principal Quantitative Modeler
# Consumer Behavior Modeler I
# Senior Quantitative Modeler
# CIB
# Fisheries Analyst/Modeler
# Demand Planner
# Operations Business Intelligence PM
# SOFTWARE ENGINEER
# Quantitative Analyst/Modeler 4
# Credit Risk Modeler
# Mathematical Modeler
# Mathematical Modeler/Analyst
# Quantitative Modeler
# Quantitative Modeler (Spatial Database Design)
# Manager, Quantitative Analysis
# Lead Quantitative Modeler
# Machine Learning Modeler
# Senior Travel Modeler
# Data Modeler
# Predictive Modeler II (Reporting & Analytics)
# ALM Assoc
# Senior Catastrophe Modeler
# Simulation Modeler
# JSM 2019
# Hydrologic/Hydraulic Modeler
# Senior Analytics Manager, Portfolio Optimization
# Experienced Actuarial Modeler (Remote Opportunities)
# Quantitative Analytics Consultant 1
# Resource Planning Forecaster/Modeler
# Water Resources Engineer/Modeler
# RET Support Engineer
# Credit Analyst
# ID
# System Analyst II
# Transaction Operations Analyst
# Investment Analyst (Private Equity)
# Vendor Risk Analyst
# Records and Information Analyst
# Risk & Portfolio Reporting Analyst
# Risk Analyst
# Credit Risk Analyst
# Risk Analyst, Due Diligence
# Principal Customer Care Compliance & Risk Analyst
# Entry Level Software Developer
# Full Stack Software Developer, Junior
# Entry Level Programmer
# Jr. Software Developer
# Software Engineer, Full Stack
# Front End Software Engineer
# BAS Engineer
# Fullstack Software Engineer
# Remote Software Development Engineer
# Associate Software Development Engineer
# Cancer
# Jr. Software Engineer
# Software Developer
# Software Engineer Apprentice
# SOFTWARE Controls Engineer
# Java Developer
# Systems Engineer
# Java Developer with AWS/GCP/Azure
# Entry level software Developer
# Software Engineer Intern
# Entry Level Technology Associate
# Software Engineer (New College Grad)
# Manager of Software Development
# Applications Engineer
# ERP Software Engineer
# Product Apparel Developer I
# sUAS Services Delivery Engineer
# Sr Frontend Engineer (Remote)
# Site Manager Software Development (w/m/x)
# DevOps USA
# Engineer I
# Development Software Engineer
# Associate Software Developer Engineer, IT â Corporate Functions, Revenue Accounting
# Software Design Engineer
# Software Engineer with Release Engineering Responsibilities
# Software Engineer (Liferay, Java, Work from Home, US Citizen, 100
# Lead Full Stack Engineer / Architect (MEAN Stack)
# Senior Full
# Sr. Full
# Software Engineer, Front End (Geospatial)
# Junior Full
# Software Engineer, Full
# Back
# Full Stack Javascript Engineer
# Full Stack Magento Engineer
# Full Stack Developer
# Senior Full Stack Engineer (On Site Position)
# WorldQuant Aligned Infrastructure Engineer
# Full Stack Engineer, Chorus
# Senior Full Stack Engineer, Chorus
# Full Stack Software Engineer (RS1768)
# Engineer, Financial Capacity Strategy (System Architecture)
# Technologist, Software Development
# Cadence Full Stack Engineer
# Frontend/Full Stack Software Engineer
# Full Stack SDE
# Digital Engineer II
# Full Stack Engineer, Enterprise Applications
# Sr. Software Engineer / PHP
# Senior Full Stack Engineer
# Full Stack Engineer, Fraud Protection
# Software Engineer, Product (Full Stack)
# Full Stack Engineer, Associate Engineering
# Full Stack Angular/.NET Software Engineer
# Front End Full Stack Engineer
# Senior Full Stack Python Engineer
# Sr. Engineer, Full Stack Developer
# Senior Full Stack Software Engineer
# Sr Full Stack Engineer (Remote)
# Full Stack DevOps Engineer
# Sponsor Funded Professional | Full Stack Engineer II
# Full Stack Software Engineer I
# Full Stack Cloud Engineer (React.JS exp)
# Front End Engineer IV (React)
# System Engineer
# Full Stack
# Software Engineer III
# Software Engineer III : Full Stack Node.js
# Full Stack Engineer (Ruby)
# AWS DevOps Engineer
# Senior Front
# QA Specialist, IT
# Senior Software Engineer, Java
# Senior Software Engineer, Ruby on Rails
# School Facilities Engineer
# Senior Application Security Engineer
# 3D Vision Software Engineer (Portland, OR)
# Quality Assurance Engineer
# Research Engineer (Computer Vision, Deep Learning)
# Associate UX Engineer
# Computer Graphics / Vision Engineer
# Design and Integration Engineer
# Mobile App Engineer
# Senior Laravel / PHP Developer (LAMP)
# Hotel Engineer
# IT Support Engineer
# Manual QA Engineer
# Maitenance hotel engineer
# PC Support Engineer
# BAS Control System Engineer (Entry Level)
# Apprentice Engineer
# Engineer in Test
# Solutions Engineer I
# Front End Engineer
# Mobile Application Test Engineer
# Engineer Software
# Software Engineer, Computer Vision
# Wind Technology Engineer
# Software Engineer, Perception
# Surveyor In Charge, Senior
# Developer
# Lead Maintenance/Engineer
# Data Entry Specialist
# Field Installer
# Field Sales Engineer â North Central
# Director, Network Engineering
# Business Integration Engineer
# Quality Engineer
# VDC Coordinator
# Temporary Application Technician
# Realty Specialist (Leasing)
# Battery Test Engineer
# Asset Reliability Engineer
# ACI Concrete Inspector/Field Soil Technician
# Engineering Geologist
# Deep Learning Research Scientist
# Manager of Analytics
# Food Packaging Field Service Engineer
# Wave Operator
# Staff Engineer
# Head of Data
# Senior SoC ML Microarchitect
# Trainer
# Principal Technology Engineer
# Full stack software engineers
# Senior Full Stack Concept Developer
# Fixed Income Full Stack Engineer
# Economist
# Software Engineer, Knowledge Platform
# Sr. Software Engineer
# Software Engineer in Test
# Research Manager
# Technical Project Manager
# Sr. Artificial Intelligence Engineer
# Certification Program Coordinator
# Demand Marketing Director, North America
# Temporary Researcher: Ethics and Technology Oversight Committee
# Materials Science Division Director
# Senior Broker
# Quantitative Associate
# Administrative Officer 2 (7376U) 27408
# User Experience Researcher
# Scientific Researcher
# Dementia Epidemiology Researcher
# Patient Services Representative (Medical and Cosmetic Dermatology)
# Storekeeper
# Assistant Biosafety Officer
# Postdoctoral Researcher
# Library Assistant / Shipping Coordinator
# Customer Service / Accounts Receivable Support
# Grant Manager
# Editorial Developer
# Associate Researcher, Department of Ophthalmology
# Associate Researcher
# Associate Researcher, Renal
# Associate Researcher, Clinical Immunology
# Associate Researcher, The Human Immune Monitoring Center (HIMC), Immunobiology Center
# Talent Researcher
# Associate Researcher, Microbiology
# Corporate Business Relationship Manager
# Early Childhood Assistant Teacher
# Distinguished User Researcher
# Qualitative UX Researcher
# STEM
# Researcher, Special Education
# Applied Social Scientist
# Computer Systems Researcher
# Digital Communications SME
# Archivist
# Clean Transportation Researcher
# Researcher, Writer, and Editor
# Administrative Officer
# Librarian (Collections Specialist) â Local History & Genealogy
# Open Source Intelligence Researcher
# SAS Programmer (603681) // US or GC // Local
# School Librarian
# UX Researcher + Designer
# Fans Voice Survey Researcher
# Cook County Court Researcher
# Lake County Court Researcher
# 5G Wireless Researcher
# Associate Director of Research Development Services
# Clin Research Interviewer II
# Prepress Specialist
# Sports Researcher
# Physical Therapist | Clinic Director | South Portland
# Nike Sports Research Lab Researcher
# SOC Post
# Consumer Insights Researcher II or Senior
# Physical Therapist Assistant
# Director of Operational Training (Healthcare)
# Research Analyst (part time, temporary)
# Assistant or Associate Researcher
# 1022

# %%
# deprecated code - retaining these keywords for seniority
#if 'junior' in job_title.lower()\
#    or ('jr' in job_title.lower() and 'sr' not in job_title.lower())\
#    or 'intern' in job_title.lower():
#    job_title_dictionary[job_title] = ['Junior Data Scientist']
#    junior_data_scientist_count += 1
#elif 'senior' in job_title.lower()\
#    or 'sr' in job_title.lower()\
#    or 'lead' in job_title.lower()\
#    or 'chief' in job_title.lower()\
#    or 'principal' in job_title.lower()\
#    or 'manager' in job_title.lower():
#    job_title_dictionary[job_title] = ['Senior Data Scientist']
#    senior_data_scientist_count += 1
